# %% [markdown]
# <a href="https://colab.research.google.com/github/Raydiator5114/Local/blob/main/2-3-9-AssignmentQuestion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3))

HIDDEN_LAYER_TYPE_1 = layers.MaxPooling2D((2, 2))

HIDDEN_LAYER_TYPE_2 = layers.Conv2D(64, (3, 3), activation='relu')

HIDDEN_LAYER_TYPE_3 = layers.MaxPooling2D((2, 2))

HIDDEN_LAYER_TYPE_4 = layers.Conv2D(64, (3, 3), activation='relu')

HIDDEN_LAYER_TYPE_5 = layers.Dense(64, activation='relu')

LAST_LAYER = layers.Dense(10)

model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       layers.Flatten(),
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
OPTIMIZER = 'adam'

LOSS = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 12s 5ms/step - loss: 2.0795 - accuracy: 0.2303 - val_loss: 1.8475 - val_accuracy: 0.3292
# Epoch 2/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6753 - accuracy: 0.3933 - val_loss: 1.6709 - val_accuracy: 0.4028
# Epoch 3/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4902 - accuracy: 0.4601 - val_loss: 1.4168 - val_accuracy: 0.4854
# Epoch 4/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3821 - accuracy: 0.5032 - val_loss: 1.3355 - val_accuracy: 0.5165
# Epoch 5/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2941 - accuracy: 0.5395 - val_loss: 1.3468 - val_accuracy: 0.5236
# Epoch 6/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.2206 - accuracy: 0.5693 - val_loss: 1.3354 - val_accuracy: 0.5342
# Epoch 7/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1587 - accuracy: 0.5934 - val_loss: 1.1717 - val_accuracy: 0.5827
# Epoch 8/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.1030 - accuracy: 0.6108 - val_loss: 1.1026 - val_accuracy: 0.6136
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.0537 - accuracy: 0.6301 - val_loss: 1.1241 - val_accuracy: 0.6015
# Epoch 10/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0092 - accuracy: 0.6471 - val_loss: 1.1010 - val_accuracy: 0.6099
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.9670 - accuracy: 0.6607 - val_loss: 1.0658 - val_accuracy: 0.6281
# Epoch 12/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9285 - accuracy: 0.6756 - val_loss: 1.0683 - val_accuracy: 0.6283
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8943 - accuracy: 0.6877 - val_loss: 1.0245 - val_accuracy: 0.6480
# Epoch 14/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8652 - accuracy: 0.6975 - val_loss: 1.0586 - val_accuracy: 0.6355
# Epoch 15/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.8333 - accuracy: 0.7088 - val_loss: 0.9997 - val_accuracy: 0.6572
# Epoch 16/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8054 - accuracy: 0.7201 - val_loss: 1.0420 - val_accuracy: 0.6430
# Epoch 17/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7759 - accuracy: 0.7304 - val_loss: 0.9586 - val_accuracy: 0.6687
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7506 - accuracy: 0.7379 - val_loss: 0.9448 - val_accuracy: 0.6754
# Epoch 19/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7262 - accuracy: 0.7487 - val_loss: 0.9485 - val_accuracy: 0.6778
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7016 - accuracy: 0.7569 - val_loss: 0.9931 - val_accuracy: 0.6624

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = 'Adam'

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.8793 - accuracy: 0.6912 - val_loss: 0.9808 - val_accuracy: 0.6637
# Epoch 2/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7888 - accuracy: 0.7238 - val_loss: 0.9082 - val_accuracy: 0.6807
# Epoch 3/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.7081 - accuracy: 0.7514 - val_loss: 0.8983 - val_accuracy: 0.6906
# Epoch 4/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6376 - accuracy: 0.7769 - val_loss: 0.8745 - val_accuracy: 0.7023
# Epoch 5/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5685 - accuracy: 0.7987 - val_loss: 0.9122 - val_accuracy: 0.7012
# Epoch 6/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.5146 - accuracy: 0.8200 - val_loss: 0.9417 - val_accuracy: 0.6961
# Epoch 7/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.4566 - accuracy: 0.8380 - val_loss: 1.0012 - val_accuracy: 0.6972
# Epoch 8/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.4087 - accuracy: 0.8540 - val_loss: 1.0403 - val_accuracy: 0.7043
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3638 - accuracy: 0.8704 - val_loss: 1.0685 - val_accuracy: 0.6970
# Epoch 10/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.3223 - accuracy: 0.8837 - val_loss: 1.1545 - val_accuracy: 0.6996
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2853 - accuracy: 0.8985 - val_loss: 1.1966 - val_accuracy: 0.7037
# Epoch 12/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.2604 - accuracy: 0.9059 - val_loss: 1.2441 - val_accuracy: 0.6975
# Epoch 13/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.2328 - accuracy: 0.9158 - val_loss: 1.4235 - val_accuracy: 0.6905
# Epoch 14/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.2186 - accuracy: 0.9212 - val_loss: 1.4747 - val_accuracy: 0.6880
# Epoch 15/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1979 - accuracy: 0.9299 - val_loss: 1.5917 - val_accuracy: 0.6893
# Epoch 16/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1864 - accuracy: 0.9333 - val_loss: 1.6029 - val_accuracy: 0.6957
# Epoch 17/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1807 - accuracy: 0.9354 - val_loss: 1.6112 - val_accuracy: 0.6965
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.1629 - accuracy: 0.9408 - val_loss: 1.7180 - val_accuracy: 0.6913
# Epoch 19/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.1588 - accuracy: 0.9430 - val_loss: 1.7580 - val_accuracy: 0.6921
# Epoch 20/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 0.1490 - accuracy: 0.9483 - val_loss: 2.0086 - val_accuracy: 0.6871
